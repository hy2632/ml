# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
my_filepath = 'input/dc-wikia-data.csv'

# %%
my_data = pd.read_csv(my_filepath, index_col = 'page_id')

# %%
my_data.head()
# Out:
#                                 name                              urlslug  \
# page_id
# 1422            Batman (Bruce Wayne)         \/wiki\/Batman_(Bruce_Wayne)
# 23387          Superman (Clark Kent)        \/wiki\/Superman_(Clark_Kent)
# 1458      Green Lantern (Hal Jordan)   \/wiki\/Green_Lantern_(Hal_Jordan)
# 1659        James Gordon (New Earth)     \/wiki\/James_Gordon_(New_Earth)
# 1576     Richard Grayson (New Earth)  \/wiki\/Richard_Grayson_(New_Earth)
#
#                       ID            ALIGN         EYE        HAIR  \
# page_id
# 1422     Secret Identity  Good Characters   Blue Eyes  Black Hair
# 23387    Secret Identity  Good Characters   Blue Eyes  Black Hair
# 1458     Secret Identity  Good Characters  Brown Eyes  Brown Hair
# 1659     Public Identity  Good Characters  Brown Eyes  White Hair
# 1576     Secret Identity  Good Characters   Blue Eyes  Black Hair
#
#                      SEX  GSM              ALIVE  APPEARANCES  \
# page_id
# ...

# %%
my_data = my_data.dropna()
# Create a line plot
sns.lineplot(x=my_data['YEAR'], y=my_data['APPEARANCES'])

# %%
import pandas as pd
dc_wikia_data = pd.read_csv("input/dc-wikia-data.csv",index_col = 'page_id').dropna()
marvel_wikia_data = pd.read_csv("input/marvel-wikia-data.csv",index_col = 'page_id').dropna()

# %%
dc_wikia_data.head()
# Out:
#                                  name                               urlslug  \
# page_id
# 1704     John Constantine (New Earth)  \/wiki\/John_Constantine_(New_Earth)
# 8856        Renee Montoya (New Earth)     \/wiki\/Renee_Montoya_(New_Earth)
# 1862            Todd Rice (New Earth)         \/wiki\/Todd_Rice_(New_Earth)
# 1597     Hartley Rathaway (New Earth)  \/wiki\/Hartley_Rathaway_(New_Earth)
# 10139      Holly Robinson (New Earth)    \/wiki\/Holly_Robinson_(New_Earth)
#
#                       ID            ALIGN         EYE        HAIR  \
# page_id
# 1704     Public Identity  Good Characters   Blue Eyes  Blond Hair
# 8856     Secret Identity  Good Characters  Brown Eyes  Black Hair
# 1862     Public Identity  Good Characters  Brown Eyes  Brown Hair
# 1597     Secret Identity  Good Characters   Blue Eyes    Red Hair
# 10139    Secret Identity  Good Characters   Blue Eyes    Red Hair
#
#                        SEX                    GSM              ALIVE  \
# page_id
# ...
